# %% [markdown]
# <a href="https://colab.research.google.com/github/imsumit8/python_beginner/blob/main/Pandas_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
# !gdown "1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /content/mckinsey.csv
# 100% 83.8k/83.8k [00:00<00:00, 108MB/s]

# %%
df = pd.read_csv('mckinsey.csv')
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['life_exp']
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
type(df['life_exp'])
# Out:
# pandas.core.series.Series

# %%
df['continent']
# Out:
# 0         Asia
# 1         Asia
# 2         Asia
# 3         Asia
# 4         Asia
#          ...
# 1699    Africa
# 1700    Africa
# 1701    Africa
# 1702    Africa
# 1703    Africa
# Name: continent, Length: 1704, dtype: object

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.shape
# Out:
# (1704, 6)

# %%
list(df.columns)
# Out:
# ['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %% [markdown]
# ## Woking with cols

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df['country'].head(10)
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# 5    Afghanistan
# 6    Afghanistan
# 7    Afghanistan
# 8    Afghanistan
# 9    Afghanistan
# Name: country, dtype: object

# %%
# cols = ['country', 'life_exp']
# df[cols]

df[['life_exp','country']].head()
# Out:
#    life_exp      country
# 0    28.801  Afghanistan
# 1    30.332  Afghanistan
# 2    31.997  Afghanistan
# 3    34.020  Afghanistan
# 4    36.088  Afghanistan

# %%
df[['country']]
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df['country'].nunique()
# Out:
# 142

# %%
# MOST IMPORTANT FUNCTION
df['country'].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df['continent'].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
df['life_exp'].max()
# Out:
# 82.603

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df = df.rename({'population': 'POPULATION'}, axis = 1)

# %%
df.head()
# Out:
#        country  year  POPULATION continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df = df.rename(columns = {'country': 'COUNTRY'})

# %%
df.head()
# Out:
#        COUNTRY  year  POPULATION continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
# all new column names.
df.columns = ['country', 'year', 'population', 'continent', 'life_exp', 'gdp_capita']

# %%
df.head()
# Out:
#        country  year  population continent  life_exp  gdp_capita
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.rename(columns = {'country': 'COUNTRYYY'}, inplace = True)

# %%
df.head()
# Out:
#      COUNTRYYY  year  population continent  life_exp  gdp_capita
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
# df = df.drop(columns = ['population'])
df.drop(columns = ['population'], inplace = True)

# %%
df.head()
# Out:
#      COUNTRYYY  year continent  life_exp  gdp_capita
# 0  Afghanistan  1952      Asia    28.801  779.445314
# 1  Afghanistan  1957      Asia    30.332  820.853030
# 2  Afghanistan  1962      Asia    31.997  853.100710
# 3  Afghanistan  1967      Asia    34.020  836.197138
# 4  Afghanistan  1972      Asia    36.088  739.981106

# %%
df = pd.read_csv("mckinsey.csv")
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df['year'] + 10
# Out:
# 0       1962
# 1       1967
# 2       1972
# 3       1977
# 4       1982
#         ...
# 1699    1997
# 1700    2002
# 1701    2007
# 1702    2012
# 1703    2017
# Name: year, Length: 1704, dtype: int64

# %%
df['YEAR+10'] = df['year'] + 10

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  YEAR+10
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314     1962
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030     1967
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710     1972
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138     1977
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106     1982

# %%
(df['gdp_cap'] * df['population'])
# Out:
# 0       6.567086e+09
# 1       7.585449e+09
# 2       8.758856e+09
# 3       9.648014e+09
# 4       9.678553e+09
#             ...
# 1699    6.508241e+09
# 1700    7.422612e+09
# 1701    9.037851e+09
# 1702    8.015111e+09
# 1703    5.782658e+09
# Length: 1704, dtype: float64

# %%
df['GDP'] =(df['gdp_cap'] * df['population'])/10**9

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  YEAR+10  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314     1962
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030     1967
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710     1972
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138     1977
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106     1982
#
#         GDP
# 0  6.567086
# 1  7.585449
# 2  8.758856
# 3  9.648014
# 4  9.678553

# %%
df['Own'] = 99

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  YEAR+10  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314     1962
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030     1967
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710     1972
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138     1977
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106     1982
#
#         GDP  Own
# 0  6.567086   99
# 1  7.585449   99
# 2  8.758856   99
# 3  9.648014   99
# 4  9.678553   99

# %%
df.drop(columns = ['YEAR+10','Own'], inplace =True)

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap       GDP
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553

# %% [markdown]
# ## Working with Rows

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap       GDP
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553
# ...           ...   ...         ...       ...       ...         ...       ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306  6.508241
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786  7.422612
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960  9.037851
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623  8.015111
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298  5.782658
#
# [1704 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap',
#        'GDP'],
#       dtype='object')

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703])

# %%
df.index = list(range(10, 1714))

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap       GDP
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553
# ...           ...   ...         ...       ...       ...         ...       ...
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306  6.508241
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786  7.422612
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960  9.037851
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623  8.015111
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298  5.782658
#
# [1704 rows x 7 columns]

# %%
df.shape
# Out:
# (1704, 7)

# %%
sample = df.head()
sample
# Out:
#         country  year  population continent  life_exp     gdp_cap       GDP
# 10  Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086
# 11  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# 12  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# 13  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# 14  Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553

# %%
sample.index = ['a', 'b', 'z', 'd', 'c']

# %%
sample
# Out:
#        country  year  population continent  life_exp     gdp_cap       GDP
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# z  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# c  Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553

# %%
sample
# Out:
#        country  year  population continent  life_exp     gdp_cap       GDP
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# z  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# c  Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553

# %%
sample.loc['z']
# Out:
# country       Afghanistan
# year                 1962
# population       10267083
# continent            Asia
# life_exp           31.997
# gdp_cap         853.10071
# GDP              8.758856
# Name: z, dtype: object

# %%
sample.loc['c']
# Out:
# country       Afghanistan
# year                 1972
# population       13079460
# continent            Asia
# life_exp           36.088
# gdp_cap        739.981106
# GDP              9.678553
# Name: c, dtype: object

# %%
sample.loc['b':'d']
# Out:
#        country  year  population continent  life_exp     gdp_cap       GDP
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# z  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap       GDP
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553
# ...           ...   ...         ...       ...       ...         ...       ...
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306  6.508241
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786  7.422612
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960  9.037851
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623  8.015111
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298  5.782658
#
# [1704 rows x 7 columns]

# %%
df.loc[1713]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# GDP             5.782658
# Name: 1713, dtype: object

# %%
df.loc[11:14]
# Out:
#         country  year  population continent  life_exp     gdp_cap       GDP
# 11  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# 12  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# 13  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# 14  Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553

# %%
demo = pd.DataFrame(['a', 'b', 'c', 'd', 'e'], index=[1, 5, 3, 7, 3])
demo
# Out:
#    0
# 1  a
# 5  b
# 3  c
# 7  d
# 3  e

# %%
demo.loc[1:3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-3982b77eccbc> in <cell line: 1>()
# ----> 1 demo.loc[1:3]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1288         if isinstance(key, slice):
#    1289             self._validate_key(key, axis)
# -> 1290             return self._get_slice_axis(key, axis=axis)
#    1291         elif com.is_bool_indexer(key):
#    1292             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap       GDP
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553
# ...           ...   ...         ...       ...       ...         ...       ...
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306  6.508241
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786  7.422612
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960  9.037851
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623  8.015111
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298  5.782658
#
# [1704 rows x 7 columns]

# %%
df.iloc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# GDP              6.567086
# Name: 10, dtype: object

# %%
df.iloc[-1]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# GDP             5.782658
# Name: 1713, dtype: object

# %%
df.iloc[2:5]
# Out:
#         country  year  population continent  life_exp     gdp_cap       GDP
# 12  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# 13  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# 14  Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
a = pd.DataFrame(['a', 'b', 'c'], index=[1, 2, 2])
a
# Out:
#    0
# 1  a
# 2  b
# 2  c

# %%
a.loc[2]
# Out:
#    0
# 2  b
# 2  c

# %%
z = pd.DataFrame({'a':[1, 2, 3],
              'b':[2, 3, 'four']})

# %%
z
# Out:
#    a     b
# 0  1     2
# 1  2     3
# 2  3  four

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      int64
#  1   b       3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
z['b'].iloc[0]
# Out:
# 2

# %%
array3d = np.array([[[1 , 2]] , [[5, 6]]])

# %%
array3d
# Out:
# array([[[1, 2]],
#
#        [[5, 6]]])

# %%
array3d.shape
# Out:
# (2, 1, 2)
